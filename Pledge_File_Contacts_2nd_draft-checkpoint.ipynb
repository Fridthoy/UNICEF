# %%
import os
import pandas as pd
import numpy as np

#plotting
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from pandas_profiling import ProfileReport
from mpl_toolkits.mplot3d import Axes3D

#import ML tools
from sklearn.cluster import KMeans #use KMeans for the numerical data
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import scale
from sklearn.preprocessing import LabelEncoder
from kmodes.kmodes import KModes #use kmodes for the categorical data
import sklearn.metrics as sm
from sklearn import datasets

from collections import defaultdict #make labelencoder able to apply dictionary

#from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# # Profiling

# %%
#Fadderskapsfil
df = pd.read_csv('Pledge_File_Contacts.csv', sep=';')

# %%
df['Installment Amount'] = df['Installment Amount'].apply(lambda x: float(x.replace(',','.')))    #replainsing commas by periods, then changing string into float
df['Total Paid Amount'].fillna('0.0', inplace=True)                                          #replacing NaN by 0
df['Total Paid Amount'] = df['Total Paid Amount'].apply(lambda x: float(x.replace(',','.'))) #replainsing all commas by periods, then changing string into float
df['Number Of Paid Installments'].fillna('0', inplace=True)                                #replacing NaN by 0

# %%
print(df.shape)
df.head(100)
# Out:
# (84405, 18)
#    Contact: Contact ID Contact: Giver ID Recurring Donation: ID  \
# 0      0031i00000RpUK9          G-233278        a091i00000BVgbk
# 1      0031i00000gezbg          G-255440        a091i00000Hj4vK
# 2      0031i00000RpWio          G-199950        a091i00000BVbeN
# 3      0031i00000Rpj4f          G-152255        a091i00000BViy6
# 4      0031i00000Ruohk          G-148462        a091i00000BVCuf
# ..                 ...               ...                    ...
# 95     0031i00000Rpomt          G-163238        a091i00000BVGEA
# 96     0031i00000RpSQB          G-224587        a091i00000BVC84
# 97     0031i00000RpK5a           G-36008        a091i00000BViru
# 98     0031i00000RpW7B          G-198711        a091i00000BVZBS
# 99     0031i00000RpjTh          G-152995        a091i00000BVYtu
#
#       Pledge Type Payment Type Open Ended Status Date Established Date Closed  \
# 0   UNICEF Fadder         Giro            Closed       18.02.2019  31.05.2019
# ...

# %%
df['First Donation Date'].iloc[84402]==df['First Donation Date'].iloc[1]
# Out:
# True

# %%
df.describe()
# Out:
#        Installment Amount  Total Paid Amount
# count        84405.000000       84405.000000
# mean           209.659697        6084.959341
# std            363.609112        6479.637719
# min              0.000000           0.000000
# 25%            100.000000         760.000000
# 50%            250.000000        3400.000000
# 75%            250.000000       10400.000000
# max         100000.000000      139400.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84405 entries, 0 to 84404
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Contact: Contact ID          84405 non-null  object
#  1   Contact: Giver ID            84405 non-null  object
#  2   Recurring Donation: ID       84405 non-null  object
#  3   Pledge Type                  84405 non-null  object
#  4   Payment Type                 84405 non-null  object
#  5   Open Ended Status            84403 non-null  object
#  6   Date Established             84405 non-null  object
#  7   Date Closed                  39417 non-null  object
#  8   First Donation Date          75033 non-null  object
#  9   Last Donation Date           75087 non-null  object
#  10  Installment Amount Currency  84405 non-null  object
#  11  Installment Amount           84405 non-null  float64
#  12  Installment Period           84405 non-null  object
# ...

# %%
profile = ProfileReport(df, title='Fadderskap profile', html={ 'style' : {'full_width':True}}) #generating the profile form pandas profiling

# %%
profile
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.9.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2020-10-20 09:50:24.839642&quot;&gt;&lt;title&gt;Fadderskap profile&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# # K-means clustering

# %%
# Scaling the variables
X1 = scale(df['Installment Amount'])
X2 = scale(df['Total Paid Amount'])
X3 = scale(df['Number Of Paid Installments'])
X = (np.array([X1,X2,X3])).T

# %%
# Building and running the model
clustering = KMeans(n_clusters=5, random_state=5) #the random state is to yield the same initialization every time you run the code
clustering.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=5, tol=0.0001, verbose=0)

# %% [markdown]
# # Plotting

# %%
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow'])
plt.scatter(x=df['Installment Amount'], y=df['Total Paid Amount'], c=color_theme[clustering.labels_], s=50)
plt.title('K-means Clustering')
plt.xlabel('Installment Amount')
plt.ylabel('Total Paid Amount')
# Out:
# Text(0, 0.5, 'Total Paid Amount')

# %% [markdown]
# # Taking away abnormalities

# %%
#check the results without the abnormality of "installment ammount = 100.000"
df2 = df.copy()
indexNr = df2[df2['Installment Amount'] == 100000].index
 
# Delete these row indexes from dataFrame
df2.drop(indexNr , inplace=True)

# %%
# Scaling the variables
X1 = scale(df2['Installment Amount'])
X2 = scale(df2['Total Paid Amount'])
X3 = scale(df2['Number Of Paid Installments'])
X = (np.array([X1,X2,X3])).T

# Building and running the model
clustering2 = KMeans(n_clusters=5, random_state=5) #the random state is to yield the same initialization every time you run the code
clustering2.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=5, tol=0.0001, verbose=0)

# %%
#ploting tot paied amount vs installment amount
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow'])
plt.scatter(x=df2['Installment Amount'], y=df2['Total Paid Amount'], c=color_theme[clustering2.labels_], s=50)
plt.title('K-means Clustering')
plt.xlabel('Installment Amount')
plt.ylabel('Total Paid Amount')
# Out:
# Text(0, 0.5, 'Total Paid Amount')

# %%
df2['Number Of Paid Installments'] = df['Number Of Paid Installments'].astype(float)
df2['Number Of Paid Installments'].dtype == df2['Installment Amount'].dtype
# Out:
# True

# %%
clustering2.labels_[0:100]
# Out:
# array([1, 1, 1, 1, 2, 3, 1, 3, 1, 1, 1, 1, 2, 3, 0, 3, 1, 1, 2, 3, 3, 3,
#        1, 3, 1, 1, 3, 3, 0, 3, 1, 3, 1, 1, 0, 1, 2, 1, 1, 1, 1, 1, 1, 1,
#        0, 2, 0, 1, 1, 1, 1, 1, 0, 3, 3, 3, 1, 1, 1, 1, 1, 2, 1, 3, 1, 1,
#        2, 1, 0, 2, 3, 2, 1, 1, 2, 1, 1, 1, 1, 0, 3, 2, 2, 3, 1, 1, 2, 2,
#        2, 0, 2, 1, 2, 0, 0, 0, 2, 1, 1, 2])

# %%
#ploting
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow'])
plt.scatter(x=df2['Number Of Paid Installments'],y=df2['Installment Amount'],  c=color_theme[clustering2.labels_], s=50)
plt.title('K-means Clustering')
plt.xlabel('Number Of Paid Installments')
plt.ylabel('Installment Amount')
# Out:
# Text(0, 0.5, 'Installment Amount')

# %% [markdown]
# # 3D Plotting

# %%
plt.figure('Fadderskap', figsize=(7,5))
ax = plt.axes(projection = '3d')
ax.scatter(df2['Number Of Paid Installments'],df2['Installment Amount'],df2['Total Paid Amount'], c=[clustering2.labels_] , cmap='Set2', s=50)

# %% [markdown]
# # K-Means with Numerical Data, Ploted with Categorical

# %%
df3 = df2.copy()
le = LabelEncoder() 
df3['Payment Type'] = le.fit_transform(df2['Payment Type'].astype('str')) #fiter fra str til int, så lagrer den det (gjør om kolonnen)

#ploting
fig, ax = plt.subplots(figsize=(5,5))
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow'])
plt.scatter(x=df3['Payment Type'],y=df3['Number Of Paid Installments'],  c=color_theme[clustering2.labels_], s=50)
plt.title('K-means Clustering')
plt.xlabel('Payment Type')
plt.ylabel('Number Of Paid Installments')

ax.set_xticks([i for i in range(len(le.classes_))]) #only the numbers in l are x-ticks
ax.set_xticklabels(le.classes_)                     #change numbers to string with the correct labels


plt.show()

# %%
df3 = df2.copy()
le = LabelEncoder() 
df3['Payment Type'] = le.fit_transform(df2['Payment Type'].astype('str')) #fiter fra str til int, så lagrer den det (gjør om kolonnen)

#ploting
fig, ax = plt.subplots(figsize=(5,5))
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow'])
plt.scatter(x=df3['Payment Type'],y=df3['Installment Amount'],  c=color_theme[clustering2.labels_], s=50)
plt.title('K-means Clustering')
plt.xlabel('Payment Type')
plt.ylabel('Installment Amount')

ax.set_xticks([i for i in range(len(le.classes_))]) #only the numbers in l are x-ticks
ax.set_xticklabels(le.classes_)                     #change numbers to string with the correct labels


plt.show()

# %%
df3 = df2.copy()
le = LabelEncoder() 
df3['Payment Type'] = le.fit_transform(df2['Payment Type'].astype('str')) #fiter fra str til int, så lagrer den det (gjør om kolonnen)

#ploting
fig, ax = plt.subplots(figsize=(5,5))
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow'])
plt.scatter(x=df3['Payment Type'],y=df3['Total Paid Amount'],  c=color_theme[clustering2.labels_], s=50)
plt.title('K-means Clustering')
plt.xlabel('Payment Type')
plt.ylabel('Total Paid Amount')

ax.set_xticks([i for i in range(len(le.classes_))]) #only the numbers in l are x-ticks
ax.set_xticklabels(le.classes_)                     #change numbers to string with the correct labels


plt.show()

# %% [markdown]
# # K-Modes with Categorical Data

# %%
#variables
n_clusters = 5

# %%
#Cleaning and structuring data
df_kmodes = df2.copy()  #create a new df, copy without outliers
df_kmodes = df_kmodes.drop(labels=['Number Of Paid Installments','Total Paid Amount', 'Installment Amount', 'Contact: Contact ID',
                                   'Contact: Giver ID','Recurring Donation: ID', 'Installment Amount Currency', 'Total Paid Amount Currency',
                                   'Date Established','Date Closed','First Donation Date','Last Donation Date', 'Installment Period'] , axis = 1)

#take away all NaNs from df
df_kmodes = df_kmodes.fillna(0)                                          #replacing NaN by 0
df_kmodes.head(10)
# Out:
#      Pledge Type Payment Type Open Ended Status   Channel  \
# 0  UNICEF Fadder         Giro            Closed        TM
# 1  UNICEF Fadder   Avtalegiro              Open       F2F
# 2  UNICEF Fadder         Giro            Closed       WEB
# 3  UNICEF Fadder         Giro            Closed       F2F
# 4  UNICEF Fadder   Avtalegiro              Open  TV EVENT
# 5  UNICEF Fadder   Avtalegiro            Closed       WEB
# 6  UNICEF Fadder         Giro            Closed       WEB
# 7  UNICEF Fadder   Avtalegiro              Open       F2F
# 8  UNICEF Fadder         Giro            Closed       F2F
# 9  UNICEF Fadder   Avtalegiro            Closed       F2F
#
#                               Campaign
# 0             2017TM rekr Verdensgaver
# 1                     Faddere D2D Oslo
# 2  2016 Digital sommer og høstkampanje
# 3                        2018 D2D Oslo
# 4   Fadderaksjon 12 TV Norge 02015 SMS
# 5                       Jemen sult WEB
# 6            2017 Umara Sommerkampanje
# ...

# %%
df_kmodes.isnull().sum()*100/df_kmodes.shape[0]  #check where if any "NaN"s left
# Out:
# Pledge Type          0.0
# Payment Type         0.0
# Open Ended Status    0.0
# Channel              0.0
# Campaign             0.0
# dtype: float64

# %%
# Preprossesing data:
df_kmodes['Open Ended Status'] = df_kmodes['Open Ended Status'].astype('str')
df_kmodes['Channel'] = df_kmodes['Channel'].astype('str')
df_kmodes['Campaign'] = df_kmodes['Campaign'].astype('str')
df_kmodes['Pledge Type'] = df_kmodes['Pledge Type'].astype('str')

#df_kmodes = df_kmodes.apply(le.fit_transform)

df_kmodes.head(10)
# Out:
#      Pledge Type Payment Type Open Ended Status   Channel  \
# 0  UNICEF Fadder         Giro            Closed        TM
# 1  UNICEF Fadder   Avtalegiro              Open       F2F
# 2  UNICEF Fadder         Giro            Closed       WEB
# 3  UNICEF Fadder         Giro            Closed       F2F
# 4  UNICEF Fadder   Avtalegiro              Open  TV EVENT
# 5  UNICEF Fadder   Avtalegiro            Closed       WEB
# 6  UNICEF Fadder         Giro            Closed       WEB
# 7  UNICEF Fadder   Avtalegiro              Open       F2F
# 8  UNICEF Fadder         Giro            Closed       F2F
# 9  UNICEF Fadder   Avtalegiro            Closed       F2F
#
#                               Campaign
# 0             2017TM rekr Verdensgaver
# 1                     Faddere D2D Oslo
# 2  2016 Digital sommer og høstkampanje
# 3                        2018 D2D Oslo
# 4   Fadderaksjon 12 TV Norge 02015 SMS
# 5                       Jemen sult WEB
# 6            2017 Umara Sommerkampanje
# ...

# %%
fit.head()
# Out:
#    Pledge Type  Payment Type  Open Ended Status  Channel  Campaign
# 0            1             2                  1       10       168
# 1            1             0                  2        3       345
# 2            1             2                  1       13       122
# 3            1             2                  1        3       173
# 4            1             0                  2       11       339

# %%
inv_fit.head()
# Out:
#      Pledge Type Payment Type Open Ended Status   Channel  \
# 0  UNICEF Fadder         Giro            Closed        TM
# 1  UNICEF Fadder   Avtalegiro              Open       F2F
# 2  UNICEF Fadder         Giro            Closed       WEB
# 3  UNICEF Fadder         Giro            Closed       F2F
# 4  UNICEF Fadder   Avtalegiro              Open  TV EVENT
#
#                               Campaign
# 0             2017TM rekr Verdensgaver
# 1                     Faddere D2D Oslo
# 2  2016 Digital sommer og høstkampanje
# 3                        2018 D2D Oslo
# 4   Fadderaksjon 12 TV Norge 02015 SMS

# %%
f = fit.copy()[-2000:-500]
fi = inv_fit.copy()[-2000:-500]

# %%
for f1 in f['Payment Type']:
# Out:
# 82405    0
# 82406    0
# 82407    0
# 82408    0
# 82409    0
#         ..
# 83900    3
# 83901    0
# 83902    0
# 83903    0
# 83904    0
# Name: Payment Type, Length: 1500, dtype: int32

# %%
d['Payment Type'].inverse_transform([0, 4])
# Out:
# array(['Avtalegiro', 'Vipps'], dtype=object)

# %%
#Encoding data from cathegorical to numerical 

#creating label encoder that can use a dictionary
d = defaultdict(LabelEncoder)

# Encoding the variable
fit = df_kmodes.apply(lambda x: d[x.name].fit_transform(x))  #fits first by label encoder. Then transforms from categorical data to numerical 

#Inverse the encoded
inv_fit = fit.apply(lambda x: d[x.name].inverse_transform(x)) #Transforms back again, from numerical to chategorical 


#Using the dictionary to label future data
#df_kmodes.apply(lambda x: d[x.name].transform(x)) #transforms new data if any (don't need it for this work I guess, only if UNICEF sendt us more and we didn't want to make a new model fit)

print(inv_fit.head(), '\n \n')
print(fit.head())
# Out:
#      Pledge Type Payment Type Open Ended Status   Channel  \
# 0  UNICEF Fadder         Giro            Closed        TM
# 1  UNICEF Fadder   Avtalegiro              Open       F2F
# 2  UNICEF Fadder         Giro            Closed       WEB
# 3  UNICEF Fadder         Giro            Closed       F2F
# 4  UNICEF Fadder   Avtalegiro              Open  TV EVENT
#
#                               Campaign
# 0             2017TM rekr Verdensgaver
# 1                     Faddere D2D Oslo
# 2  2016 Digital sommer og høstkampanje
# 3                        2018 D2D Oslo
# 4   Fadderaksjon 12 TV Norge 02015 SMS
#
#
#    Pledge Type  Payment Type  Open Ended Status  Channel  Campaign
# 0            1             2                  1       10       168
# 1            1             0                  2        3       345
# 2            1             2                  1       13       122
# 3            1             2                  1        3       173
# ...

# %% [markdown]
# ## K-Modes Cao

# %%
km_cao = KModes(n_clusters=5, init = "Cao", n_init = 1, verbose=1)
fitClusters_cao = km_cao.fit_predict(df_kmodes)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 13923, cost: 115534.0
# Run 1, iteration: 2/100, moves: 503, cost: 115534.0

# %%
fitClusters_cao
# Out:
# array([1, 0, 1, ..., 0, 4, 4], dtype=uint16)

# %%
clusterCentroidsDf = pd.DataFrame(km_cao.cluster_centroids_)
clusterCentroidsDf.columns = df_kmodes.columns

# %%
clusterCentroidsDf #shows the 5 different clusters and their correstponding modes
# Out:
#    Pledge Type  Payment Type  Open Ended Status  Channel  Campaign
# 0            1             0                  2        3        73
# 1            1             2                  1        3       152
# 2            1             0                  1       11       395
# 3            0             3                  2        8       433
# 4            1             0                  1        3       200

# %%
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow']) #chose five clusters, need five distrinct colors
#colors = cm.nipy_spectral(fitClusters_huang/ n_clusters)  #autmaticly extract n_cluster (5) colors, but not distincs

fig, ax = plt.subplots() #initializing figure figsize=(5,5)
ax.scatter(df_kmodes['Payment Type'],df_kmodes['Channel'], marker='.', 
           s=30, lw=0, alpha=0.7, c=color_theme[fitClusters_cao], edgecolor='k') #color_theme[fitClusters_huang] --> each number gets a speciffic color
xticks = [i for i in range(len(df_kmodes['Payment Type'].unique()))]
#ax.set_xticks(xticks)
#ax.set_xticklabels(d['Payment Type'].inverse_transform(xticks)) #payment type as cathegorical data
ax.set_title('K-modes Clustering')
#ax.set_xlabel('Payment Type')
#ax.set_ylabel('Campaign')
plt.show()

# %% [markdown]
# ## K-modes Huang

# %%
km_huang = KModes(n_clusters=n_clusters, init = "Huang", n_init = 1, verbose=1)
fitClusters_huang = km_huang.fit_predict(fit)  #outputs a labeled vector
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 13825, cost: 117492.0
# Run 1, iteration: 2/100, moves: 3, cost: 117492.0

# %%
# displaying the different clusters
print(np.unique(km_huang.labels_))
print(fitClusters_huang)
# Out:
# [0 1 2 3 4]
# [0 1 0 ... 1 3 3]

# %%
fit.head()
inv_fit.head()
# Out:
#      Pledge Type Payment Type Open Ended Status   Channel  \
# 0  UNICEF Fadder         Giro            Closed        TM
# 1  UNICEF Fadder   Avtalegiro              Open       F2F
# 2  UNICEF Fadder         Giro            Closed       WEB
# 3  UNICEF Fadder         Giro            Closed       F2F
# 4  UNICEF Fadder   Avtalegiro              Open  TV EVENT
#
#                               Campaign
# 0             2017TM rekr Verdensgaver
# 1                     Faddere D2D Oslo
# 2  2016 Digital sommer og høstkampanje
# 3                        2018 D2D Oslo
# 4   Fadderaksjon 12 TV Norge 02015 SMS

# %%
inv_fit['Payment Type']
#inv_fit.head()
# Out:
# 0              Giro
# 1        Avtalegiro
# 2              Giro
# 3              Giro
# 4        Avtalegiro
#             ...
# 84400         Mobil
# 84401    Avtalegiro
# 84402    Avtalegiro
# 84403    Avtalegiro
# 84404    Avtalegiro
# Name: Payment Type, Length: 84404, dtype: object

# %%
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow']) #chose five clusters, need five distrinct colors
#colors = cm.nipy_spectral(fitClusters_huang/ n_clusters)  #autmaticly extract n_cluster (5) colors, but not distincs

fig, ax = plt.subplots() #initializing figure figsize=(5,5)
ax.scatter(df_kmodes['Payment Type'],df_kmodes['Channel'], marker='.', 
           s=30, lw=0, alpha=0.7, c=color_theme[fitClusters_huang], edgecolor='k') #color_theme[fitClusters_huang] --> each number gets a speciffic color
xticks = [i for i in range(len(df_kmodes['Payment Type'].unique()))]
#ax.set_xticks(xticks)
#ax.set_xticklabels(d['Payment Type'].inverse_transform(xticks)) #payment type as cathegorical data
ax.set_title('K-modes Clustering')
#ax.set_xlabel('Payment Type')
#ax.set_ylabel('Campaign')
plt.show()

# %%
#should also evaluate nr of clusters. See this forum: https://datascience.stackexchange.com/questions/64455/how-to-evaluate-the-k-modes-clusters

# %%
plt.scatter(x=df_kmodes['Payment Type'],y=df_kmodes['Channel'], marker='.', s=30, lw=0, alpha=0.7, c=color_theme[fitClusters_huang], edgecolor='k') 
plt.title('K-modes Clustering')
plt.xlabel('Payment Type')
plt.ylabel('Channel')
# Out:
# Text(0, 0.5, 'Channel')

# %% [markdown]
# # K-modes using numerical and cathegorical data!

# %%
df_all = df2.copy() #making a copy of df without the abonrmality

# %%
df_all = df_all.drop(labels=['Contact: Contact ID',
                                   'Contact: Giver ID','Recurring Donation: ID', 'Installment Amount Currency', 'Total Paid Amount Currency',
                                   'Date Established','Date Closed','First Donation Date','Last Donation Date', 'Installment Period'] , axis = 1)

#take away all NaNs from df
df_all = df_all.fillna(0)  #replacing NaN by 0
df_all['Open Ended Status'] = df_all['Open Ended Status'].astype('str')
df_all['Channel'] = df_all['Channel'].astype('str')
df_all['Campaign'] = df_all['Campaign'].astype('str')
df_all['Pledge Type'] = df_all['Pledge Type'].astype('str')

df_all.head(10)
# Out:
#      Pledge Type Payment Type Open Ended Status  Installment Amount   Channel  \
# 0  UNICEF Fadder         Giro            Closed               250.0        TM
# 1  UNICEF Fadder   Avtalegiro              Open               250.0       F2F
# 2  UNICEF Fadder         Giro            Closed               250.0       WEB
# 3  UNICEF Fadder         Giro            Closed               350.0       F2F
# 4  UNICEF Fadder   Avtalegiro              Open               200.0  TV EVENT
# 5  UNICEF Fadder   Avtalegiro            Closed              1000.0       WEB
# 6  UNICEF Fadder         Giro            Closed               100.0       WEB
# 7  UNICEF Fadder   Avtalegiro              Open               200.0       F2F
# 8  UNICEF Fadder         Giro            Closed               250.0       F2F
# 9  UNICEF Fadder   Avtalegiro            Closed               250.0       F2F
#
#                               Campaign  Number Of Paid Installments  \
# ...

# %%
#for i, val in enumerate(arr): 
  #  print(i, val, arr[i])

# %%
# Make the numerical data categorical such that it can be used in K-modes

#Installment Amount
def categorizes_installment(amount):    #cathegorizes amount to different clusters
    if amount<50: 
        return 'under 50'
    if amount<200: 
        return '50-199 kr'
    if amount<400: 
        return '200-599 kr'
    if amount<1000: 
        return '400-1000 kr'
    else: 
        return 'above 1000 kr'    

#Total Paid Amount. Mean is 6085. Max is 139400.
def categorizes_total(amount): 
    if amount<50: 
        return 'under 200'
    if amount<1000: 
        return '200-1000 kr'
    if amount<5000: 
        return '1000-5000 kr'
    if amount<10000: 
        return '5000-10000 kr'
    else: 
        return 'above 10000 kr' 

# Number Of Paid Installments. Mean is 32. Max is 208
def categorizes_nr(nr): 
    if nr<1: 
        return 'less than 1 paid'
    if nr<10: 
        return '1-9 paid'
    if nr<30: 
        return '10-29 paid'
    if nr<100: 
        return '30-99 kr'
    else: 
        return 'above 100 kr'  # 30 paiments in this category

    
df_fit = df_all.copy()
df_fit['Installment Amount'] = list(map(categorizes_installment,df_fit['Installment Amount']))
df_fit['Total Paid Amount'] = list(map(categorizes_total, df_fit['Total Paid Amount']))
df_fit['Number Of Paid Installments'] = list(map(categorizes_nr, df_fit['Number Of Paid Installments']))

df_fit.head()
# Out:
#      Pledge Type Payment Type Open Ended Status Installment Amount   Channel  \
# 0  UNICEF Fadder         Giro            Closed         200-599 kr        TM
# 1  UNICEF Fadder   Avtalegiro              Open         200-599 kr       F2F
# 2  UNICEF Fadder         Giro            Closed         200-599 kr       WEB
# 3  UNICEF Fadder         Giro            Closed         200-599 kr       F2F
# 4  UNICEF Fadder   Avtalegiro              Open         200-599 kr  TV EVENT
#
#                               Campaign Number Of Paid Installments  \
# 0             2017TM rekr Verdensgaver            less than 1 paid
# 1                     Faddere D2D Oslo                    1-9 paid
# 2  2016 Digital sommer og høstkampanje                  10-29 paid
# 3                        2018 D2D Oslo                    1-9 paid
# 4   Fadderaksjon 12 TV Norge 02015 SMS                    30-99 kr
#
#   Total Paid Amount
# 0         under 200
# 1       200-1000 kr
# 2      1000-5000 kr
# ...

# %%
type(df_fit['Total Paid Amount'][1])
# Out:
# str

# %%
#creating label encoder that can use a dictionary
d_le = defaultdict(LabelEncoder)

# Encoding the variable
df_fit = df_fit.apply(lambda x: d_le[x.name].fit_transform(x))  #fits first by label encoder. Then transforms from categorical data to numerical 

#fit.head()

# %%
type(df_all['Number Of Paid Installments'][1])
# Out:
# numpy.float64

# %%
# cao k-modes method
km_all = KModes(n_clusters=5, init = "Cao", n_init = 1, verbose=1)
fitClusters_all = km_all.fit_predict(df_all)
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 12658, cost: 308639.0
# Run 1, iteration: 2/100, moves: 496, cost: 308639.0

# %%
# plotting
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow']) #chose five clusters, need five distrinct colors
#colors = cm.nipy_spectral(fitClusters_huang/ n_clusters)  #autmaticly extract n_cluster (5) colors, but not distincs

fig, ax = plt.subplots() #initializing figure figsize=(5,5)
ax.scatter(df_all['Payment Type'],df_all['Channel'], marker='.', 
           s=30, lw=0, alpha=0.7, c=color_theme[fitClusters_all], edgecolor='k') #color_theme[fitClusters_huang] --> each number gets a speciffic color
xticks = [i for i in range(len(df_all['Payment Type'].unique()))]
#ax.set_xticks(xticks)
#ax.set_xticklabels(d['Payment Type'].inverse_transform(xticks)) #payment type as cathegorical data
ax.set_title('K-modes Clustering')
ax.set_xlabel('Payment Type')
ax.set_ylabel('Campaign')
plt.show()

# %%
# plotting
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow']) #chose five clusters, need five distrinct colors
fig, ax = plt.subplots() 
ax.scatter(df_all['Total Paid Amount'],df_all['Channel'], marker='.', 
           s=30, lw=0, alpha=0.7, c=color_theme[fitClusters_all], edgecolor='k') #color_theme[fitClusters_huang] --> each number gets a speciffic color
ax.set_title('K-modes Clustering')
ax.set_xlabel('Total Paid Amount')
ax.set_ylabel('Channel')
plt.show()

# %%
df_all.head()
# Out:
#      Pledge Type Payment Type Open Ended Status  Installment Amount   Channel  \
# 0  UNICEF Fadder         Giro            Closed               250.0        TM
# 1  UNICEF Fadder   Avtalegiro              Open               250.0       F2F
# 2  UNICEF Fadder         Giro            Closed               250.0       WEB
# 3  UNICEF Fadder         Giro            Closed               350.0       F2F
# 4  UNICEF Fadder   Avtalegiro              Open               200.0  TV EVENT
#
#                               Campaign  Number Of Paid Installments  \
# 0             2017TM rekr Verdensgaver                          0.0
# 1                     Faddere D2D Oslo                          1.0
# 2  2016 Digital sommer og høstkampanje                         13.0
# 3                        2018 D2D Oslo                          3.0
# 4   Fadderaksjon 12 TV Norge 02015 SMS                         68.0
#
#    Total Paid Amount
# 0                0.0
# 1              250.0
# ...

# %%
# plotting
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow']) #chose five clusters, need five distrinct colors
fig, ax = plt.subplots() 
ax.scatter(df_fit['Total Paid Amount'],df_fit['Payment Type'], marker='.', 
           s=30, lw=0, alpha=0.7, c=color_theme[fitClusters_all], edgecolor='k') #color_theme[fitClusters_huang] --> each number gets a speciffic color
ax.set_title('K-modes Clustering')
ax.set_xlabel('Total Paid Amount')
ax.set_ylabel('Payment Type')
plt.show()

# %%
# plotting
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow']) #chose five clusters, need five distrinct colors
fig, ax = plt.subplots() 
ax.scatter(df_all['Total Paid Amount'],df_all['Payment Type'], marker='.', 
           s=30, lw=0, alpha=0.7, c=color_theme[fitClusters_all], edgecolor='k') #color_theme[fitClusters_huang] --> each number gets a speciffic color
ax.set_title('K-modes Clustering')
ax.set_xlabel('Total Paid Amount')
ax.set_ylabel('Payment Type')
plt.show()

# %%
# plotting
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow']) #chose five clusters, need five distrinct colors
fig, ax = plt.subplots() 
ax.scatter(df_all['Total Paid Amount'],df_all['Installment Amount'], marker='.', 
           s=30, lw=0, alpha=0.7, c=color_theme[fitClusters_all], edgecolor='k') #color_theme[fitClusters_huang] --> each number gets a speciffic color
ax.set_title('K-modes Clustering')
ax.set_xlabel('Total Paid Amount')
ax.set_ylabel('Installment Amount')
plt.show()

# %%
# plotting
color_theme = np.array(['darkgray','lightsalmon','powderblue', 'aqua', 'greenyellow']) #chose five clusters, need five distrinct colors
fig, ax = plt.subplots() 
ax.scatter(df_all['Total Paid Amount'],df_all['Channel'], marker='.', 
           s=30, lw=0, alpha=0.7, c=color_theme[fitClusters_all], edgecolor='k') #color_theme[fitClusters_huang] --> each number gets a speciffic color
ax.set_title('K-modes Clustering')
ax.set_xlabel('Total Paid Amount')
ax.set_ylabel('Channel')
plt.show()

# %% [markdown]
# # 2 DO next!
# #### Now that you understand how to use k-modes and k-means, it is time to see if there is any interrelationships in the data.
# #### 1. Try changing the numer of clusters. Will this extract any patterns?
# #### 2. Try taking away some of the features. Are there any reduntant features? Any features that are correlated?
# #### 3. Are there any obvious differences between cao and huang?
